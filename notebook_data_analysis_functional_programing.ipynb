# %%
# les imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\valen\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\valen\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64 (2).dll
# C:\Users\valen\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
df = pd.read_csv("output_3.csv", sep="|")
df
# Out:
#                              product_name    renamed nutrition_grade_fr  \
# 0           Aloe Vera Grape & Apple Juice  Beverages                  e
# 1                         Boisson au soja  Beverages                NaN
# 2                            Lait de coco  Beverages                  d
# 3                           Soursop Juice  Beverages                  e
# 4         Boisson a base de jus de lychee  Beverages                  e
# ...                                   ...        ...                ...
# 5859        Boisson au soja (soy bean 8%)  Beverages                  b
# 5860                 Yeo's Soy Bean Drink  Beverages                  e
# 5861                      Mantou Sandwich      Bread                  b
# 5862                         Mini Paratha      Bread                  c
# 5863  Tartines craquantes bio au sarrasin      Bread                  a
#
#       energy_100g  fat_100g  saturated-fat_100g  sugars_100g  sodium_100g  \
# 0           155.0       2.5                 0.1          8.5     0.039370
# 1           235.2       0.8                 0.5          8.2     0.034000
# 2           774.0       2.5                17.0          2.0     0.019685
# 3           184.0       0.0                 0.0         11.0     0.031000
# 4           192.0       0.0                 0.0         11.3     0.000000
# ...           ...       ...                 ...          ...          ...
# 5859        214.0       1.1                 0.2          7.8     0.000000
# 5860        222.0       2.5                 0.2          8.3     0.003937
# 5861       1218.0       2.0                 1.0         14.0     0.023622
# 5862       1309.0      15.0                 9.0          5.1     0.354331
# 5863       1643.0       2.8                 0.6          2.6     0.267717
#
#       salt_100g  proteins_100g
# 0       0.10000            0.1
# 1       0.08636            2.0
# 2       0.05000            1.6
# 3       0.07874            0.0
# 4       0.00000            0.0
# ...         ...            ...
# 5859    0.00000            2.0
# 5860    0.01000            2.0
# 5861    0.06000            8.0
# 5862    0.90000            6.0
# 5863    0.68000           13.0
#
# [5864 rows x 10 columns]

# %%
# Paramétrage de l'affichage
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_colwidth', None)

# Afficher les premières lignes du dataset
print(df.head())
# Out:
#                       product_name    renamed nutrition_grade_fr  energy_100g  \
# 0    Aloe Vera Grape & Apple Juice  Beverages                  e        155.0
# 1                  Boisson au soja  Beverages                NaN        235.2
# 2                     Lait de coco  Beverages                  d        774.0
# 3                    Soursop Juice  Beverages                  e        184.0
# 4  Boisson a base de jus de lychee  Beverages                  e        192.0
#
#    fat_100g  saturated-fat_100g  sugars_100g  sodium_100g  salt_100g  \
# 0       2.5                 0.1          8.5     0.039370    0.10000
# 1       0.8                 0.5          8.2     0.034000    0.08636
# 2       2.5                17.0          2.0     0.019685    0.05000
# 3       0.0                 0.0         11.0     0.031000    0.07874
# 4       0.0                 0.0         11.3     0.000000    0.00000
#
#    proteins_100g
# 0            0.1
# 1            2.0
# 2            1.6
# 3            0.0
# 4            0.0

# %%
# Pie chart Nutri score : Répartition des produits par nutriscore
plt.figure(figsize=(8,8))
plt.title('Répartition des Nutriscores', size=20)
df['nutrition_grade_fr'].value_counts(normalize=True).sort_index().plot(kind='pie', autopct='%1.0f%%')
plt.axis('equal')
plt.show()

# %%
# Bar chart Categories : Répartition des produits par catégories
plt.figure(figsize=(16,10))
plt.title('Répartition des catégories (%)', size=20)
plt.xlabel('Catégories', size=15, fontweight='bold')
plt.ylabel('Proportion (%)', size=15, fontweight='bold')
df['renamed'].value_counts(normalize=True).plot(kind='bar')
plt.show()

# %%
# Sélectionner uniquement les colonnes numériques
numeric_cols = df.select_dtypes(include=[np.number]).columns

# Calculer la matrice de corrélation sur les colonnes numériques
correlation_matrix = df[numeric_cols].corr()

# Créer le heatmap
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=True)
plt.show()

# %%
x = input()
y = input()
print(x+y)
# Out:
# 36

# %%
print("a", "b", "c", sep="sep")
# Out:
# asepbsepc

# %%
x = 1 // 5 + 1 / 5
print(x)
# Out:
# 0.2

# %%
dct = {'one': 'two', 'three': 'one', 'two': 'three'}
v = dct['three']

for k in range(len(dct)):
    v = dct[v]

print(v)
# Out:
# one

# %%
def fun(x, y):
    if x == y:
        return x
    else:
        return fun(x, y-1)


print(fun(0, 3))
# Out:
# 0

# %%
tup = (1, 2, 4, 8)
tup = tup[-2:-1]
print(tup)
tup = tup[-1]
print(tup)
# Out:
# (4,)
# 4

# %%
dct = {}
dct['1'] = (1, 2)
dct['2'] = (2, 1)

for x in dct.keys():
    print(dct[x][1], end="")
# Out:
# 21

# %%
def fun(inp=2, out=3):
    return inp * out


print(fun(out=2))
# Out:
# 4

# %%
lst = [[x for x in range(3)] for y in range(3)]

for r in range(3):
    for c in range(3):
        if lst[r][c] % 2 != 0:
            print("#")
# Out:
# #
# #
# #

# %%
try:
    value = input("Enter a value: ")
    print(int(value)/len(value))
except ValueError:
    print("Bad input...")
except ZeroDivisionError:
    print("Very bad input...")
except TypeError:
    print("Very very bad input...")
except:
    print("Booo!")
# Out:
# 0.0
